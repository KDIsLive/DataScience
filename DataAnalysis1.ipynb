# %%
import pandas as pd
data= pd.read_csv(r"C:\Users\kushw\OneDrive\Documents\Dissertation\FloodbyPostCode\open_flood_risk_by_postcode.csv")
data.head()
# Out:
#    TR23 0PR  \N  None \N.1 \N.2 \N.3  87897  15021  49.953605  -6.352647
# 0  TR23 0WA  \N  None   \N   \N   \N  87903  15077  49.954111  -6.352609
# 1  TR22 0PL  \N  None   \N   \N   \N  88364   8478  49.895171  -6.340873
# 2  TR24 0QE  \N  None   \N   \N   \N  88849  15298  49.956586  -6.339638
# 3  TR24 0QL  \N  None   \N   \N   \N  88857  15392  49.957433  -6.339603
# 4  TR24 0QB  \N  None   \N   \N   \N  88887  15424  49.957736  -6.339211

# %%
from dbfread import DBF
table = DBF(r'C:\Users\kushw\OneDrive\Documents\Dissertation\FloodbyPostCode\Floodplains_from_2016.dbf')

# %%
len(table)
# Out:
# 385

# %%
list1 = list(table)

# %%
print(list1[0])
# Out:
# OrderedDict([('OBJECTID', 1), ('FLD_AR_ID', '110001_651'), ('FLD_ZONE', 'X'), ('FLOODWAY', ''), ('SFHA_TF', 'F'), ('STATIC_BFE', -9999.0), ('V_DATUM', ''), ('DEPTH', -9999), ('LEN_UNIT', ''), ('VELOCITY', -9999), ('VEL_UNIT', ''), ('AR_REVERT', ''), ('BFE_REVERT', -9999), ('DEP_REVERT', -9999), ('SOURCE_CIT', '110001_STUDY1'), ('HYDRO_ID', ''), ('CST_MDL_ID', ''), ('ZONE', 'X'), ('SHAPE_Leng', 3980.9620518320335), ('SHAPE_Area', 202854.2479746709), ('DFIRM_ID', '110001'), ('VERSION_ID', '1.1.1.0'), ('ZONE_SUBTY', 'AREA OF MINIMAL FLOOD HAZARD'), ('AR_SUBTRV', ''), ('STUDY_TYP', 'NP'), ('DUAL_ZONE', ''), ('URL', 'https://msc.fema.gov/portal/home')])
